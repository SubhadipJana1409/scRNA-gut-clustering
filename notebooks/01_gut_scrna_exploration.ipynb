# %% [markdown]
# # Day 20 — scRNA-seq Gut Cell Clustering
# Interactive exploration with scanpy.

# %%
import sys; sys.path.insert(0, '..')
import scanpy as sc
from src.data import load_simulated
from src.visualization.plots import set_style
set_style()
# %matplotlib inline

# %%
adata = load_simulated(n_cells=500, n_genes=500, random_seed=42)
print(adata)

# %%
# Run full pipeline
from src.main import main
adata = main(['--out-dir', 'outputs_notebook'])
